# %% [markdown]
# ## Quote Crawler - goodreads.com

# %%
import requests
from bs4 import BeautifulSoup
import pickle
import os
from langdetect import detect_langs

import sqlite3

# %%
conn = sqlite3.connect('quotes.db')
c = conn.cursor()

def create_table():
    c.execute(
        """
        CREATE TABLE IF NOT EXISTS quotes(
            quote TEXT UNIQUE ON CONFLICT IGNORE,
            author TEXT,
            book TEXT,
            likes INT,
            english TEXT
        )
        """
    )

def insert_row(quote, author, book, likes, english):
    c.execute(
        """
        INSERT INTO quotes (quote, author, book, likes, english)
        VALUES (?, ?, ?, ?, ?)
        """,
            (quote, author, book, likes, english))
    conn.commit()

create_table()

# %%
TAG = 'inspirational'
MAX_QUOTES = 5000

# this character signifies the end of the quote
h_bar = '―'

def clean_quote(text):
    to_remove = '()[]_~'
    
    for bad_char in to_remove:
        text = text.replace(bad_char, '')
        
    text = text.replace('“\n', '“').replace('\n”', '”')
    text.replace('&', 'and')
    
    return text

def likely_english(text):
    return any(item.lang=='en' for item in detect_langs(text))

# %%
page = 1
exit_flag = False
processed_quotes = 0

while processed_quotes < MAX_QUOTES:
    
    print(f'Crawling page: {page}')
    
    html = requests.get(f'https://www.goodreads.com/quotes/tag/{TAG}?page={page}').content
    soup = BeautifulSoup(html, 'html.parser')
    
    raw_quotes = soup.findAll('div', {'class': 'quoteDetails'})
    
    if not raw_quotes:
        break
    
    for q in raw_quotes:
        
        if processed_quotes >= MAX_QUOTES:
            exit_flag=True
            break

        qt = q.find('div', {'class' : 'quoteText'})
        quote = qt.get_text('\n', strip=' ').split(h_bar)[0].strip(' ,\t\n')
        author = qt.find('span', {'class' : 'authorOrTitle'}).get_text().strip(' ,\t\n')
        book = qt.find('a', {'class' : 'authorOrTitle'})
        book = 'Unknown' if not book else book.get_text().strip(' ,\t\n')
        likes = int(q.find('div', {'class' : 'quoteFooter'}).find('a', {'class' : 'smallText'}).get_text().split(' ')[0])

        quote = clean_quote(quote)
        english = 'Yes' if likely_english(quote) else 'No'

        insert_row(quote, author, book, likes, english)
        
        processed_quotes += 1
            
    print(f'Total quotes scraped: {processed_quotes}', end = '\n\n')
    
    if exit_flag == True:
        break
    
    page += 1
# Out:
# Crawling page: 1
# Total quotes scraped: 30
#
# Crawling page: 2
# Total quotes scraped: 60
#
# Crawling page: 3
# Total quotes scraped: 90
#
# Crawling page: 4
# Total quotes scraped: 120
#
# Crawling page: 5
# Total quotes scraped: 150
#
# Crawling page: 6
# Total quotes scraped: 180
#
# Crawling page: 7
# Total quotes scraped: 210
#
# Crawling page: 8
# Total quotes scraped: 240
#
# Crawling page: 9
# Total quotes scraped: 270
#
# Crawling page: 10
# Total quotes scraped: 300
#
# Crawling page: 11
# Total quotes scraped: 330
#
# Crawling page: 12
# Total quotes scraped: 360
#
# Crawling page: 13
# Total quotes scraped: 390
#
# Crawling page: 14
# Total quotes scraped: 420
#
# Crawling page: 15
# Total quotes scraped: 450
#
# Crawling page: 16
# Total quotes scraped: 480
#
# Crawling page: 17
# Total quotes scraped: 510
#
# Crawling page: 18
# Total quotes scraped: 540
#
# Crawling page: 19
# Total quotes scraped: 570
#
# Crawling page: 20
# Total quotes scraped: 600
#
# Crawling page: 21
# Total quotes scraped: 630
#
# Crawling page: 22
# Total quotes scraped: 660
#
# Crawling page: 23
# Total quotes scraped: 690
#
# Crawling page: 24
# Total quotes scraped: 720
#
# Crawling page: 25
# Total quotes scraped: 750
#
# Crawling page: 26
# Total quotes scraped: 780
#
# Crawling page: 27
# Total quotes scraped: 810
#
# Crawling page: 28
# Total quotes scraped: 840
#
# Crawling page: 29
# Total quotes scraped: 870
#
# Crawling page: 30
# Total quotes scraped: 900
#
# Crawling page: 31
# Total quotes scraped: 930
#
# Crawling page: 32
# Total quotes scraped: 960
#
# Crawling page: 33
# Total quotes scraped: 990
#
# Crawling page: 34
# Total quotes scraped: 1020
#
# Crawling page: 35
# Total quotes scraped: 1050
#
# Crawling page: 36
# Total quotes scraped: 1080
#
# Crawling page: 37
# Total quotes scraped: 1110
#
# Crawling page: 38
# Total quotes scraped: 1140
#
# Crawling page: 39
# Total quotes scraped: 1170
#
# Crawling page: 40
# Total quotes scraped: 1200
#
# Crawling page: 41
# Total quotes scraped: 1230
#
# Crawling page: 42
# Total quotes scraped: 1260
#
# Crawling page: 43
# Total quotes scraped: 1290
#
# Crawling page: 44
# Total quotes scraped: 1320
#
# Crawling page: 45
# Total quotes scraped: 1350
#
# Crawling page: 46
# Total quotes scraped: 1380
#
# Crawling page: 47
# Total quotes scraped: 1410
#
# Crawling page: 48
# Total quotes scraped: 1440
#
# Crawling page: 49
# Total quotes scraped: 1470
#
# Crawling page: 50
# Total quotes scraped: 1500
#
# Crawling page: 51
# Total quotes scraped: 1530
#
# Crawling page: 52
# Total quotes scraped: 1560
#
# Crawling page: 53
# Total quotes scraped: 1590
#
# Crawling page: 54
# Total quotes scraped: 1620
#
# Crawling page: 55
# Total quotes scraped: 1650
#
# Crawling page: 56
# Total quotes scraped: 1680
#
# Crawling page: 57
# Total quotes scraped: 1710
#
# Crawling page: 58
# Total quotes scraped: 1740
#
# Crawling page: 59
# Total quotes scraped: 1770
#
# Crawling page: 60
# Total quotes scraped: 1800
#
# Crawling page: 61
# Total quotes scraped: 1830
#
# Crawling page: 62
# Total quotes scraped: 1860
#
# Crawling page: 63
# Total quotes scraped: 1890
#
# Crawling page: 64
# Total quotes scraped: 1920
#
# Crawling page: 65
# Total quotes scraped: 1950
#
# Crawling page: 66
# Total quotes scraped: 1980
#
# Crawling page: 67
# Total quotes scraped: 2010
#
# Crawling page: 68
# Total quotes scraped: 2040
#
# Crawling page: 69
# Total quotes scraped: 2070
#
# Crawling page: 70
# Total quotes scraped: 2100
#
# Crawling page: 71
# Total quotes scraped: 2130
#
# Crawling page: 72
# Total quotes scraped: 2160
#
# Crawling page: 73
# Total quotes scraped: 2190
#
# Crawling page: 74
# Total quotes scraped: 2220
#
# Crawling page: 75
# Total quotes scraped: 2250
#
# Crawling page: 76
# Total quotes scraped: 2280
#
# Crawling page: 77
# Total quotes scraped: 2310
#
# Crawling page: 78
# Total quotes scraped: 2340
#
# Crawling page: 79
# Total quotes scraped: 2370
#
# Crawling page: 80
# Total quotes scraped: 2400
#
# Crawling page: 81
# Total quotes scraped: 2430
#
# Crawling page: 82
# Total quotes scraped: 2460
#
# Crawling page: 83
# Total quotes scraped: 2490
#
# Crawling page: 84
# Total quotes scraped: 2520
#
# Crawling page: 85
# Total quotes scraped: 2550
#
# Crawling page: 86
# Total quotes scraped: 2580
#
# Crawling page: 87
# Total quotes scraped: 2610
#
# Crawling page: 88
# Total quotes scraped: 2640
#
# Crawling page: 89
# Total quotes scraped: 2670
#
# Crawling page: 90
# Total quotes scraped: 2700
#
# Crawling page: 91
# Total quotes scraped: 2730
#
# Crawling page: 92
# Total quotes scraped: 2760
#
# Crawling page: 93
# Total quotes scraped: 2790
#
# Crawling page: 94
# Total quotes scraped: 2820
#
# Crawling page: 95
# Total quotes scraped: 2850
#
# Crawling page: 96
# Total quotes scraped: 2880
#
# Crawling page: 97
# Total quotes scraped: 2910
#
# Crawling page: 98
# Total quotes scraped: 2940
#
# Crawling page: 99
# Total quotes scraped: 2970
#
# Crawling page: 100
# Total quotes scraped: 3000
#
# Crawling page: 101
# Total quotes scraped: 3030
#
# Crawling page: 102
# Total quotes scraped: 3060
#
# Crawling page: 103
# Total quotes scraped: 3090
#
# Crawling page: 104
# Total quotes scraped: 3120
#
# Crawling page: 105
# Total quotes scraped: 3150
#
# Crawling page: 106
# Total quotes scraped: 3180
#
# Crawling page: 107
# Total quotes scraped: 3210
#
# Crawling page: 108
# Total quotes scraped: 3240
#
# Crawling page: 109
# Total quotes scraped: 3270
#
# Crawling page: 110
# Total quotes scraped: 3300
#
# Crawling page: 111
# Total quotes scraped: 3330
#
# Crawling page: 112
# Total quotes scraped: 3360
#
# Crawling page: 113
# Total quotes scraped: 3390
#
# Crawling page: 114
# Total quotes scraped: 3420
#
# Crawling page: 115
# Total quotes scraped: 3450
#
# Crawling page: 116
# Total quotes scraped: 3480
#
# Crawling page: 117
# Total quotes scraped: 3510
#
# Crawling page: 118
# Total quotes scraped: 3540
#
# Crawling page: 119
# Total quotes scraped: 3570
#
# Crawling page: 120
# Total quotes scraped: 3600
#
# Crawling page: 121
# Total quotes scraped: 3630
#
# Crawling page: 122
# Total quotes scraped: 3660
#
# Crawling page: 123
# Total quotes scraped: 3690
#
# Crawling page: 124
# Total quotes scraped: 3720
#
# Crawling page: 125
# Total quotes scraped: 3750
#
# Crawling page: 126
# Total quotes scraped: 3780
#
# Crawling page: 127
# Total quotes scraped: 3810
#
# Crawling page: 128
# Total quotes scraped: 3840
#
# Crawling page: 129
# Total quotes scraped: 3870
#
# Crawling page: 130
# Total quotes scraped: 3900
#
# Crawling page: 131
# Total quotes scraped: 3930
#
# Crawling page: 132
# Total quotes scraped: 3960
#
# Crawling page: 133
# Total quotes scraped: 3990
#
# Crawling page: 134
# Total quotes scraped: 4020
#
# Crawling page: 135
# Total quotes scraped: 4050
#
# Crawling page: 136
# Total quotes scraped: 4080
#
# Crawling page: 137
# Total quotes scraped: 4110
#
# Crawling page: 138
# Total quotes scraped: 4140
#
# Crawling page: 139
# Total quotes scraped: 4170
#
# Crawling page: 140
# Total quotes scraped: 4200
#
# Crawling page: 141
# Total quotes scraped: 4230
#
# Crawling page: 142
# Total quotes scraped: 4260
#
# Crawling page: 143
# Total quotes scraped: 4290
#
# Crawling page: 144
# Total quotes scraped: 4320
#
# Crawling page: 145
# Total quotes scraped: 4350
#
# Crawling page: 146
# Total quotes scraped: 4380
#
# Crawling page: 147
# Total quotes scraped: 4410
#
# Crawling page: 148
# Total quotes scraped: 4440
#
# Crawling page: 149
# Total quotes scraped: 4470
#
# Crawling page: 150
# Total quotes scraped: 4500
#
# Crawling page: 151
# Total quotes scraped: 4530
#
# Crawling page: 152
# Total quotes scraped: 4560
#
# Crawling page: 153
# Total quotes scraped: 4590
#
# Crawling page: 154
# Total quotes scraped: 4620
#
# Crawling page: 155
# Total quotes scraped: 4650
#
# Crawling page: 156
# Total quotes scraped: 4680
#
# Crawling page: 157
# Total quotes scraped: 4710
#
# Crawling page: 158
# Total quotes scraped: 4740
#
# Crawling page: 159
# Total quotes scraped: 4770
#
# Crawling page: 160
# Total quotes scraped: 4800
#
# Crawling page: 161
# Total quotes scraped: 4830
#
# Crawling page: 162
# Total quotes scraped: 4860
#
# Crawling page: 163
# Total quotes scraped: 4890
#
# Crawling page: 164
# Total quotes scraped: 4920
#
# Crawling page: 165
# Total quotes scraped: 4950
#
# Crawling page: 166
# Total quotes scraped: 4980
#
# Crawling page: 167
# Total quotes scraped: 5000

# %%
c.close()
conn.close()
